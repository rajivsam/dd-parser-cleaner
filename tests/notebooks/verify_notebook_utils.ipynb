# %%
from dd_cleaner.notebook_utils import (
    init_notebook_session, 
    get_raw_data, 
    get_cleaned_data, 
    get_tagged_entities,
    get_attributes_by_tag
)

# Initialize the session pointing to the parent directory (tests/)
coord, artifacts_df = init_notebook_session("..")

# Display the artifacts table
artifacts_df
# Out:
# ✅ Notebook session initialized for workspace: /home/rajiv/programming/dd-parser-cleaner/tests
# Available Artifacts:
#                      Artifact Name                                  File Name  \
# 0                         Raw Data                          sba_loans_raw.csv
# 1                     Cleaned Data                    sba_loans_raw_clean.csv
# 2                User Cleaned Data             sba_loans_raw_user_cleaned.csv
# 3             Tagged Entities (DD)         sba_loans_raw_analysis_results.csv
# 4  Cleaning Recommendations Report                cleaning_recommendations.md
# 5                 Profiling Report          sba_loans_raw_profiling_report.md
# 6                   Handshake File  sba_loans_raw_parser_cleaner_handshake.md
# 7                  Quarantine File               sba_loans_raw_quarantine.csv
# 8               Metadata Authority           sba_loans_raw_metadata_table.csv
#
#                                             Location  Exists
# 0                             data/sba_loans_raw.csv    True
# 1            data/dd_cleaner/sba_loans_raw_clean.csv    True
# 2     data/dd_cleaner/sba_loans_raw_user_cleaned.csv    True
# 3  documents/dd_analysis_results/sba_loans_raw_an...    True
# 4   documents/dd_cleaner/cleaning_recommendations.md    True
# 5  documents/dd_cleaner/sba_loans_raw_profiling_r...    True
# 6  documents/dd_cleaner/sba_loans_raw_parser_clea...    True
# 7       data/quarantine/sba_loans_raw_quarantine.csv   False
# 8   data/dd_cleaner/sba_loans_raw_metadata_table.csv   False
#                      Artifact Name                                  File Name  \
# 0                         Raw Data                          sba_loans_raw.csv
# 1                     Cleaned Data                    sba_loans_raw_clean.csv
# 2                User Cleaned Data             sba_loans_raw_user_cleaned.csv
# 3             Tagged Entities (DD)         sba_loans_raw_analysis_results.csv
# 4  Cleaning Recommendations Report                cleaning_recommendations.md
# 5                 Profiling Report          sba_loans_raw_profiling_report.md
# 6                   Handshake File  sba_loans_raw_parser_cleaner_handshake.md
# 7                  Quarantine File               sba_loans_raw_quarantine.csv
# 8               Metadata Authority           sba_loans_raw_metadata_table.csv
#
#                                             Location  Exists
# 0                             data/sba_loans_raw.csv    True
# 1            data/dd_cleaner/sba_loans_raw_clean.csv    True
# 2     data/dd_cleaner/sba_loans_raw_user_cleaned.csv    True
# 3  documents/dd_analysis_results/sba_loans_raw_an...    True
# 4   documents/dd_cleaner/cleaning_recommendations.md    True
# 5  documents/dd_cleaner/sba_loans_raw_profiling_r...    True
# 6  documents/dd_cleaner/sba_loans_raw_parser_clea...    True
# 7       data/quarantine/sba_loans_raw_quarantine.csv   False
# 8   data/dd_cleaner/sba_loans_raw_metadata_table.csv   False

# %%
# Load the raw data
df_raw = get_raw_data(coord)

# Load the cleaned data produced by the pipeline
df_clean = get_cleaned_data(coord)

# Load the metadata/tagged entities
df_tags = get_tagged_entities(coord)

# %%
df_tags
# Out:
#                Field Name                                         Definition  \
# 0                asofdate                    Date when the data was recorded
# 1                 program  Indicator of whether loan was approved under S...
# 2              locationid                        SBA's unique lender ID code
# 3                borrname                                      Borrower name
# 4              borrstreet                            Borrower street address
# 5                borrcity                                      Borrower city
# 6               borrstate                                     Borrower state
# 7                 borrzip                                  Borrower zip code
# 8           grossapproval                                  Total loan amount
# 9            approvaldate                         Date the loan was approved
# 10             approvalfy                  Fiscal year the loan was approved
# 11  firstdisbursementdate     Date of first loan disbursement (if available)
# 12       processingmethod  Specific processing method loan was approved u...
# 13             subprogram  Subprogram description - specific subprogram l...
# 14           terminmonths                                Length of loan term
# 15              naicscode  North American Industry Classification System ...
# 16       naicsdescription  North American Industry Classification System ...
# 17          franchisecode                                     Franchise Code
# 18          franchisename                     Franchise Name (if applicable)
# 19          projectcounty                        County where project occurs
# 20           projectstate                         State where project occurs
# 21      sbadistrictoffice                                SBA district office
# 22  congressionaldistrict        Congressional district where project occurs
# 23           businesstype  Borrower Business Type - Individual, Partnersh...
# 24            businessage  SBA began collecting the following business ag...
# 25             loanstatus  Current status of loan:  \n• COMMIT = Undisbur...
# 26         paidinfulldate         Date loan was paid in full (if applicable)
# 27          chargeoffdate          Date SBA charged off loan (if applicable)
# 28   grosschargeoffamount  Total loan balance charged off (includes guara...
# 29          jobssupported  Total Jobs Created + Jobs Retained as reported...
# 30          collateralind  An indicator whether the SBA lender reported t...
#
#    physical_type logical_type         attribute_name  \
# 0       datetime     datetime               asofdate
# 1            int      numeric                program
# 2            int      numeric             locationid
# 3            str         text               borrname
# 4            str         text             borrstreet
# 5            str         text               borrcity
# 6            str  categorical              borrstate
# 7            int      numeric                borrzip
# 8            int      numeric          grossapproval
# 9       datetime     datetime           approvaldate
# 10           int      numeric             approvalfy
# 11      datetime     datetime  firstdisbursementdate
# 12           str  categorical       processingmethod
# 13           str  categorical             subprogram
# 14           int      numeric           terminmonths
# 15           int      numeric              naicscode
# 16           str         text       naicsdescription
# 17         float      numeric          franchisecode
# 18           str  categorical          franchisename
# 19           str         text          projectcounty
# 20           str  categorical           projectstate
# 21           str  categorical      sbadistrictoffice
# 22           int      numeric  congressionaldistrict
# 23           str  categorical           businesstype
# 24           str  categorical            businessage
# 25           str  categorical             loanstatus
# 26      datetime     datetime         paidinfulldate
# 27      datetime     datetime          chargeoffdate
# 28         float      numeric   grosschargeoffamount
# 29           int      numeric          jobssupported
# 30         float      numeric          collateralind
#
#           provisional_entity_assignment static_dynamic
# 0                    Logical Categories           none
# 1                    Logical Categories           none
# 2   Logical Category: Unique Identifier           none
# 3                          Organization           none
# 4                            Geographic           none
# 5                            Geographic           none
# 6                    Logical Categories           none
# 7                            geographic           none
# 8                    Logical Categories           none
# 9                    Logical Categories           none
# 10                     Logical Category           none
# 11                               Person           none
# 12                   Logical Categories           none
# 13                   Logical Categories           none
# 14                   Logical Categories           none
# 15                   Logical Categories           none
# 16                   Logical Categories           none
# 17                   Logical Categories           none
# 18                         Organization           none
# 19                    Geographic Entity           none
# 20                     Logical Category           none
# 21                    Conceptual Entity           none
# 22                           geographic           none
# 23                   Logical Categories           none
# 24                   Logical Categories           none
# 25                   Logical Categories           none
# 26                     Logical Category           none
# 27                   Logical Categories           none
# 28                   Logical Categories           none
# 29                   Logical Categories           none
# 30                   Logical Categories           none

# %%
df_clean
# Out:
#          asofdate  program  locationid                        borrname  \
# 0       3/31/2026      504      188194       Sai Ram Hospitality, Inc.
# 1       3/31/2026      504      188242              Martin Harper P.C.
# 2       3/31/2026      504      613875     Patchwerk Recording Studios
# 3       3/31/2026      504      188333                 HAMMES SEED INC
# 4       3/31/2026      504      188210              PriceKubecka, PLLC
# ...           ...      ...         ...                             ...
# 116340  3/31/2026      504      188130  Dr. Wesley Cowan, D.M.D., Inc.
# 116341  3/31/2026      504      188130             Juan C Yordan MD PA
# 116342  3/31/2026      504      188130              Marco Hangars, LLC
# 116343  3/31/2026      504      188130                     Lisa Ammons
# 116344  3/31/2026      504      188130                   PC Fresh Wash
#
#                              borrstreet          borrcity borrstate  borrzip  \
# 0              1010 E. Columbian Blvd..        Litchfield        IL    62056
# 1                   3 E. Ramona Avenue.  Colorado springs        CO    80905
# 2                 1094 Hemphill Avenue.           Atlanta        GA    30318
# 3                       1123 120th Rd..            Seneca        KS    66538
# 4       465 West President George Bush.        Richardson        TX    75080
# ...                                 ...               ...       ...      ...
# 116340          16680 N. Dale Mabry Hwy             Tampa        FL    33618
# 116341      929 US Hwy 441/27, Unit 601         Lady Lake        FL    32159
# 116342                 2006 Mainsail Dr            NAPLES        FL    34114
# 116343                  13331 Gulf Blvd     Madeira Beach        FL    33708
# 116344                  45 Exchange Way         Braselton        GA    30517
#
#         grossapproval approvaldate  ...                   sbadistrictoffice  \
# 0              810000    10/2/2009  ...           ILLINOIS DISTRICT OFFICE
# 1              127000    10/2/2009  ...           COLORADO DISTRICT OFFICE
# 2             1287000    10/2/2009  ...            GEORGIA DISTRICT OFFICE
# 3              273000    10/2/2009  ...        KANSAS CITY DISTRICT OFFICE
# 4             1500000    10/2/2009  ...  DALLAS / FT WORTH DISTRICT OFFICE
# ...               ...          ...  ...                                 ...
# 116340         314000    6/22/2020  ...      SOUTH FLORIDA DISTRICT OFFICE
# 116341         363000    6/22/2020  ...      NORTH FLORIDA DISTRICT OFFICE
# 116342        1017000    6/22/2020  ...      SOUTH FLORIDA DISTRICT OFFICE
# 116343          82000    6/22/2020  ...      SOUTH FLORIDA DISTRICT OFFICE
# 116344        1252000    6/22/2020  ...            GEORGIA DISTRICT OFFICE
#
#        congressionaldistrict businesstype  \
# 0                       13.0  CORPORATION
# 1                        5.0  CORPORATION
# 2                        5.0  CORPORATION
# 3                        2.0  CORPORATION
# 4                        3.0  CORPORATION
# ...                      ...          ...
# 116340                  14.0  CORPORATION
# 116341                  11.0  CORPORATION
# 116342                  19.0  CORPORATION
# 116343                  13.0   INDIVIDUAL
# 116344                   9.0  CORPORATION
#
#                                    businessage       loanstatus  \
# 0         Less than 4 years old but at least 3  PREPAID IN FULL
# 1         Less than 4 years old but at least 3  PREPAID IN FULL
# 2         Less than 4 years old but at least 3  PREPAID IN FULL
# 3         Less than 4 years old but at least 3          CURRENT
# 4         Less than 4 years old but at least 3         CANCELED
# ...                                        ...              ...
# 116340       Existing or more than 2 years old          CURRENT
# 116341       Existing or more than 2 years old          CURRENT
# 116342  Startup, Loan Funds will Open Business          CURRENT
# 116343       Existing or more than 2 years old         CANCELED
# 116344  Startup, Loan Funds will Open Business  PREPAID IN FULL
#
#         paidinfulldate chargeoffdate grosschargeoffamount jobssupported  \
# 0            9/30/2016           NaN                  0.0             0
# 1           11/30/2020           NaN                  0.0             1
# 2            4/30/2018           NaN                  0.0             5
# 3                  NaN           NaN                  0.0             1
# 4                  NaN           NaN                  0.0            13
# ...                ...           ...                  ...           ...
# 116340             NaN           NaN                  0.0             5
# 116341             NaN           NaN                  0.0             0
# 116342             NaN           NaN                  0.0             4
# 116343             NaN           NaN                  0.0             0
# 116344       2/28/2025           NaN                  0.0             8
#
#        collateralind
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# ...              ...
# 116340          True
# 116341          True
# 116342          True
# 116343          True
# 116344          True
#
# [116345 rows x 31 columns]
